# %% [markdown]
# Item B

# %% [markdown]
# Todos os Ks

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#definindo N e k
N = 200
k1 = 1
k2 = 10
k3 = 20
k4 = 50

#parametros de x e y
start = -4
stop = 4
mean = 1
sigma = 2

#definindo x e y periodo e w0
x = np.linspace(start,stop,N,endpoint=True)
y = np.random.normal(mean, sigma, len(x))
periodo = 4
w0 = 2*np.pi/periodo

#define coeficiente ak
def ak(k):
    if k == 0:
      a = 1
    else:
      a = (np.sin(2*k*w0))/(2*k*w0) + 1j*(1/(k*w0))*((np.sin(2*k*w0))/(2*k*w0)-(np.cos(2*k*w0)))
    return a.sum()/a.size

#define soma de fourier
def f(x, Nh):
    f = np.array([2*ak(i)*np.exp(1j*i*w0*x) for i in range(1,Nh+1)])
    return f.sum()


#aplica soma de fourier para diferentes Ns

Fourier1 = np.array([f(t,k1).real for t in x])
Fourier2 = np.array([f(t,k2).real for t in x])
Fourier3 = np.array([f(t,k3).real for t in x])
Fourier4 = np.array([f(t,k4).real for t in x])

#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Série de Fourier para uma onda Dente de Serra")
ax.plot(x , Fourier1 +1 , label = (" k = %d " % k1))
ax.plot(x , Fourier2 +1 , label = (" k = %d " % k2))
ax.plot(x , Fourier3 +1 , label = (" k = %d " % k3))
ax.plot(x , Fourier4 +1 , label = (" k = %d " % k4))
ax.plot(x, 1 -2*signal.sawtooth(w0*(x-2) ))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('x(t)')
ax.set_xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# k = 1

# %%
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Série de Fourier para uma onda Dente de Serra")
ax.plot(x , Fourier1 +1 , label = (" k = %d " % k1))
ax.plot(x, 1 -2*signal.sawtooth(w0*(x-2) ))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('x(t)')
ax.set_xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# k = 10

# %%
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Série de Fourier para uma onda Dente de Serra")
ax.plot(x , Fourier2 +1 ,label = (" k = %d " % k2))
ax.plot(x, 1 -2*signal.sawtooth(w0*(x-2) ))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('x(t)')
ax.set_xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# k = 20

# %%
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Série de Fourier para uma onda Dente de Serra")
ax.plot(x , Fourier3 +1 , label = (" k = %d " % k3))
ax.plot(x, 1 -2*signal.sawtooth(w0*(x-2) ))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('x(t)')
ax.set_xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# k = 50

# %%
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Série de Fourier para uma onda Dente de Serra")
ax.plot(x , y_Fourier_4 +1 , label = (" k = %d " % k4))
ax.plot(x, 1 -2*signal.sawtooth(w0*(x-2) ))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('x(t)')
ax.set_xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# Item C

# %%
import numpy as np
from scipy import signal
from scipy.integrate import quad

start = -6
stop = 6
mean = 1
sigma = 2
N = 200
x = np.linspace(start,stop,N,endpoint=True)
y = np.random.normal(mean, sigma, len(x))
k = [1, 10, 20, 50]
w0 = 2*np.pi/tau

def ak(k):
    if k == 0:
      a = 1
    else:
      a = (np.sin(2*k*w0))/(2*k*w0) + 1j*(1/(k*w0))*((np.sin(2*k*w0))/(2*k*w0)-(np.cos(2*k*w0)))
    return a.sum()/a.size

def f(x, Nh):
    f = np.array([2*ak(i)*np.exp(1j*i*w0*x) for i in range(1,Nh+1)] )
    return f.sum()

def g(x):
    sawtooth = 1-2*signal.sawtooth(w0*(x-2))
    return sawtooth

def integrandreal(x,Nh):
    return (1/4)*(g(x) - 1 - f(x,Nh).real)**2

Resposta = [quad(integrandreal, -2, 2, args = (k[i])) for i in range(len(k))]

print(Resposta)
# Out:
# [(0.5227638641946312, 5.420021470216862e-10), (0.07713892619337943, 1.3754023065327796e-09), (0.039532140056045086, 7.229430982318445e-10), (0.016050356161802257, 1.3031514710974542e-08)]

# %% [markdown]
# Item D

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

start = -4
stop = 4
mean = 1
sigma = 2
N = 200
k = 50
x = np.linspace(start,stop,N,endpoint=True)
y = np.random.normal(mean, sigma, len(x))
mak = []
contador_w0 = []
T = 4
w0 = 2*np.pi/T
def ak(k):
    if k == 0:
      a = 1
    else:
      a = (np.sin(2*k*w0))/(2*k*w0) + 1j*(1/(k*w0))*((np.sin(2*k*w0))/(2*k*w0)-(np.cos(2*k*w0)))
    return a
for i in range(-50,0):
    contador_w0.append(i)
    mak.append(np.abs(ak(i)))

contador_w0.append(0)
mak.append(1)
for i in range(1,51):
    contador_w0.append(i)
    mak.append(np.abs(ak(i)))

plt.figure(figsize=(15,8), facecolor='yellow')
plt.stem(contador_w0,mak, use_line_collection= True)
plt.xlabel("W0")
plt.ylabel("|ck|")
plt.title("Resultado do módulo de ak")
plt.show()

# %% [markdown]
# Item E

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

start = -4
stop = 4
mean = 1
sigma = 2
N = 200
k = 50
x = np.linspace(start,stop,N,endpoint=True)
y = np.random.normal(mean, sigma, len(x))
hw = []
ha = []
contador_wc = []
c = 1*10**(-6)
r = 100*10**3
wc = 1/r/c

def h(w):
    if w == 0:
      h = 1
    else:
      h = 1/(1 - 1j*(wc/w))
    return h

for i in range(-50,0):
    contador_wc.append(i)
    hw.append(np.abs(h(i)))
    ha.append(np.angle(h(i)))

contador_wc.append(0)
hw.append(0)
ha.append(0)

for i in range(1,51):
    contador_wc.append(i)
    hw.append(np.abs(h(i)))
    ha.append(np.angle(h(i)))


plt.figure(figsize=(30,8), facecolor='yellow')
plt.plot(contador_wc,hw)
plt.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
plt.xlabel("w")
plt.ylabel("|H(jw)|")
plt.title("Resultado do módulo de H")
plt.show()

# %%
plt.figure(figsize=(30,8), facecolor='yellow')
plt.plot(contador_wc,ha)
plt.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
plt.xlabel("w")
plt.ylabel("<H(jw)")
plt.title("Resultado da fase de H")
plt.show()

# %% [markdown]
# Item F

# %%
import numpy as np
import matplotlib.pyplot as plt

start = -6
stop = 6
N = 50
n = 1000
x = np.linspace(start,stop,n,endpoint=True)


c = 1*10**(-6)
r = 100*10**3
wc = 1/r/c
T = 4
w0 = 2*np.pi/T

def ak(k):
    if k == 0:
      a = 1
    else:
      a = (np.sin(2*k*w0))/(2*k*w0) + 1j*(1/(k*w0))*((np.sin(2*k*w0))/(2*k*w0)-(np.cos(2*k*w0)))
    return a

def h(w):
    if w == 0:
      h = 0
    else:
      h = 1/(1 - 1j*(wc/w))
    return h

def y(x, Nh):
    y = np.array([ak(i)*h(i)*np.exp(1j*i*w0*x) for i in range(-Nh,Nh+1)] )
    return y.sum()

Fourier = [y(t,N).real for t in x]

plt.figure(figsize=(30,8), facecolor='yellow')
plt.plot(x ,Fourier , label = 'Resposta ao circuito filtro passa-alta ao sinal dente de serra aproximada')
plt.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("Função y(t)")
plt.show()
