# %% [markdown]
# Item A

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def chebyshev(w, wc, n, e):
    Tn = calcula_coeficientes(w, wc, n)
    return np.abs(1/(np.sqrt(1+e**2 * Tn**2 * (w/wc))))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
e = 0.2
n = [1,2,3,4,5]

HC= np.array([chebyshev(w,wc,i,e)for i in n])




#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão A")
for i in range(len(n)):
    ax.plot(w , HC[i] , label = f'n={n[i]}')
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H_C(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item B

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def chebyshev(w, wc, n, e):
    Tn = calcula_coeficientes(w, wc, n)
    return np.abs(1/(np.sqrt(1+e**2 * Tn**2 * (w/wc))))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
e = [0.1,0.3,0.5,0.7,0.9]
n = 3

HC= np.array([chebyshev(w,wc,n,i)for i in e])




#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão B")
for i in range(len(e)):
    ax.plot(w , HC[i] , label = f'$\epsilon={e[i]}$')
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H_C(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item C

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn

def butterworth(w, wc, n):
    return np.abs(1/np.sqrt(1 + (w/wc)**(2*n)))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
n = [1,2,3,4,5]

HB= np.array([butterworth(w,wc,i)for i in n])




#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão C")
for i in range(len(n)):
    ax.plot(w , HB[i] , label = (" n = %d " % i))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H_B(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item D

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5


X= np.array([retangulo(i,wc)for i in w])




#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão D")
ax.plot(w , X)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|X_(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   app.launch_new_instance()
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item E

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def H_idealjw(w, wc):
  if np.abs(w) <= wc:
    return 1
  else:
    return 0

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5


Hi= np.array([H_idealjw(i,wc)for i in w])




#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão E")
ax.plot(w , Hi)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H_ideal_(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def H_idealjw(w, wc):
  if np.abs(w) <= wc:
	  return 1
  else:
	  return 0



def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5

X= np.array([retangulo(i,wc)for i in w])

Hi= np.array([H_idealjw(i,wc)for i in w])

Yijw_vetor = np.abs(np.multiply(X, Hi))


#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão E")
ax.plot(w , Yijw_vetor)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|Y_ideal(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in double_scalars
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item F

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal



w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
e = 0.9
n = 3

HC = chebyshev(w, wc, n, e)



#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão F")
ax.plot(w , HC)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H_C(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item E

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def chebyshev(w, wc, n, e):
    Tn = calcula_coeficientes(w, wc, n)
    return np.abs(1/(np.sqrt(1+e**2 * Tn**2 * (w/wc))))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
e = 0.9
n = 3

HC= chebyshev(w,wc,n,e)


def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)


X= np.array([retangulo(i,wc)for i in w])

YCjw_vetor = np.abs(np.multiply(X, HC))

#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão F")
ax.plot(w , YCjw_vetor)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|Y_C(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in double_scalars
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item G

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn

def butterworth(w, wc, n):
    return np.abs(1/np.sqrt(1 + (w/wc)**(2*n)))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
n = 2

HB= np.array([butterworth(i,wc,n)for i in w])




#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão G")
ax.plot(w , HB)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H_B(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %% [markdown]
# Item F

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn

def butterworth(w, wc, n):
    return np.abs(1/np.sqrt(1 + (w/wc)**(2*n)))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
n = 2

HB= np.array([butterworth(i,wc,n)for i in w])


def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)


X= np.array([retangulo(i,wc)for i in w])

YBjw_vetor = np.abs(np.multiply(X, HB))

#plota
fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão G")
ax.plot(w , YBjw_vetor)
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|Y_B(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in double_scalars
# No handles with labels found to put in legend.
# Text(0.5, 0, '$\\omega[rad/s]$')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal


#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn


def chebyshev(w, wc, n, e):
    Tn = calcula_coeficientes(w, wc, n)
    return np.abs(1/(np.sqrt(1+e**2 * Tn**2 * (w/wc))))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
e = 0.9
n1 = 3

HC= chebyshev(w,wc,n1,e)


def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)


X= np.array([retangulo(i,wc)for i in w])

YCjw_vetor = np.abs(np.multiply(X, HC))

wc = 5
n2 = 2

HB= np.array([butterworth(i,wc,n2)for i in w])


def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)

def H_idealjw(w, wc):
  if np.abs(w) <= wc:
    return 1
  else:
    return 0


Hi= np.array([H_idealjw(i,wc)for i in w])
YBjw_vetor = np.abs(np.multiply(X, butterworth_vetor))


fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão H")
ax.plot(w , Hi, label = (" $|H_i(j\omega)|$"))
ax.plot(w , HC, label = (" $|H_C(j\omega)|$"))
ax.plot(w , HB, label = (" $|H_B(j\omega)|$"))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|H(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
# Text(0.5, 0, '$\\omega[rad/s]$')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal


#define calcula coeficientes
def calcula_coeficientes(w, wc, n):

    Tn = np.zeros((w.size,))
    # determina os valores dos coeficientes segundo as express�es padronizadas
    Tn[abs(w) < wc] = np.cos(n*np.arccos(w[abs(w) < wc] / wc))
    Tn[abs(w) >= wc] = np.cosh(n*np.arccosh(w[abs(w) >= wc] / wc))
    return Tn

#define polinômio de chebyshev
def chebyshev(w, wc, n, e):
    Tn = calcula_coeficientes(w, wc, n)
    return np.abs(1/(np.sqrt(1+e**2 * Tn**2 * (w/wc))))

w = np.linspace(0, 20, 100, endpoint = True)
wc = 5
e = 0.9
n1 = 3

HC= chebyshev(w,wc,n1,e)

#define polinômio de chebyshev
def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)


X= np.array([retangulo(i,wc)for i in w])



wc = 5
n2 = 2

HB= np.array([butterworth(i,wc,n2)for i in w])

#define polinômio de chebyshev
def retangulo(w, wc):
    return np.abs(2*(np.sin((w*np.pi)/(wc)))/w)
#define polinômio de chebyshev
def H_idealjw(w, wc):
  if np.abs(w) <= wc:
    return 1
  else:
    return 0


Hi= np.array([H_idealjw(i,wc)for i in w])

Yijw_vetor = np.abs(np.multiply(X, Hi))
YBjw_vetor = np.abs(np.multiply(X, HB))
YCjw_vetor = np.abs(np.multiply(X, HC))



fig = plt.figure(figsize=(8, 6), dpi=80,facecolor='yellow')
ax = fig.add_subplot(111)
plt.title("Questão H")
ax.plot(w , Yijw_vetor, label = (" $|Y_i(j\omega)|$"))
ax.plot(w , YCjw_vetor, label = (" $|Y_C(j\omega)|$"))
ax.plot(w , YBjw_vetor, label = (" $|Y_B(j\omega)|$"))
ax.grid(True, color='dimgray', linestyle='--', linewidth=0.5)
ax.set_axisbelow(True)
ax.legend()
ax.set_ylabel('$|Y(j\omega)|$')
ax.set_xlabel('$\omega[rad/s]$')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
# Text(0.5, 0, '$\\omega[rad/s]$')
